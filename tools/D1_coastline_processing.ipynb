# %%
from shapely.geometry import Polygon, MultiPolygon
import geopandas as gpd
import rasterio
from rasterio.windows import from_bounds as wfb
from rasterio.transform import Affine
from rasterio.io import MemoryFile
import os
from rasterio.features import rasterize
from rasterio.transform import from_bounds as tfb
import numpy as np

# %%
def drop_z(geom):
    if geom.has_z:
        # Extract only XY coords, drop Z
        if geom.geom_type == 'Polygon':
            exterior = [(x, y) for x, y, z in geom.exterior.coords]
            interiors = [[(x, y) for x, y, z in ring.coords] for ring in geom.interiors]
            return Polygon(exterior, interiors)
        elif geom.geom_type == 'MultiPolygon':
            polygons = []
            for poly in geom.geoms:
                exterior = [(x, y) for x, y, z in poly.exterior.coords]
                interiors = [[(x, y) for x, y, z in ring.coords] for ring in poly.interiors]
                polygons.append(Polygon(exterior, interiors))
            return MultiPolygon(polygons)
    else:
        return geom
    
def add_overlapping_id_with_buffer(gdf1, gdf2, id_col='id', new_col='srtm_id', crs_proj='EPSG:3857', buffer_m=500):
    # Reproject both GeoDataFrames to projected CRS for accurate distance calculations
    gdf1_proj = gdf1.to_crs(crs_proj).copy()
    gdf2_proj = gdf2.to_crs(crs_proj).copy()

    gdf1_proj[new_col] = None
    sindex = gdf2_proj.sindex

    for idx1, geom1 in gdf1_proj.geometry.items():
        possible_matches_index = list(sindex.intersection(geom1.bounds))
        possible_matches = gdf2_proj.iloc[possible_matches_index]

        precise_matches = possible_matches[possible_matches.intersects(geom1)]
        if precise_matches.empty:
            continue

        centroid1 = geom1.centroid
        # Create buffer of specified meters around centroid1
        centroid_buffer = centroid1.buffer(buffer_m)

        # Select geometries whose centroid intersects with the buffer zone
        candidate_matches = precise_matches[precise_matches.geometry.centroid.intersects(centroid_buffer)]

        if not candidate_matches.empty:
            # Assign the id of the first matched geometry (you can modify to handle multiple)
            gdf1_proj.at[idx1, new_col] = candidate_matches.iloc[0][id_col]

    # Optionally transform back to original CRS
    gdf1_final = gdf1_proj.to_crs(gdf1.crs)

    cols = list(gdf1_final.columns)             
    cols.insert(1, cols.pop(cols.index('id')))    
    gdf1_final  = gdf1_final[cols] 
    gdf1_final 

    return gdf1_final

def get_country_tiles(geojson_path, srtm_zip_path, countries_path, analysis_id):
    # Load data
    gmw_tiles = gpd.read_file(geojson_path)
    srtm_grid = gpd.read_file(f"zip://{srtm_zip_path}")

    # Correct tile data and add srtm id
    gmw_tiles['geometry'] = gmw_tiles['geometry'].apply(drop_z)
    gmw_tiles = add_overlapping_id_with_buffer(gmw_tiles, srtm_grid, id_col='id', new_col='id', crs_proj='EPSG:3857')

    # Filter to overlapping with country
    countries = gpd.read_file(countries_path)
    country = countries[countries['name'] == analysis_id]

    if gmw_tiles.crs != country.crs:
        country = country.to_crs(gmw_tiles.crs)

    ind_sindex = country.sindex
    overlapping_idx = []

    for idx, geom in gmw_tiles.geometry.items():
        possible_matches_idx = list(ind_sindex.intersection(geom.bounds))
        possible_matches = country.iloc[possible_matches_idx]
        if not possible_matches[possible_matches.intersects(geom)].empty:
            overlapping_idx.append(idx)

    gmw_tiles_country = gmw_tiles.loc[overlapping_idx].copy()

    print("Get country tiles")
    print(f"Projection gmw_tiles: {gmw_tiles.crs}")
    print(f"Projection srtm_grid: {srtm_grid.crs}")
    print(f"Projection countries: {countries.crs}")
    print(f"Projection gmw_tiles_country: {gmw_tiles_country.crs}")
    
    print(f"Found {len(gmw_tiles_country)} polygons overlapping {analysis_id}.")
    print("\n")
    return gmw_tiles_country

def process_clark_dataset(gmw_tiles_country, year, input_tiff_path, output_tiff_folder):
    # Ensure output directory exists
    os.makedirs(output_tiff_folder, exist_ok=True)

    # Reproject to raster CRS
    with rasterio.open(input_tiff_path) as src:
        raster_crs = src.crs

    gmw_tiles_country_reprojected = gmw_tiles_country.to_crs(raster_crs)

    print("Process Clark dataset")
    print("Projection input_tiff_path:", raster_crs)
    print("Projection gmw_tiles_country_reprojected:", gmw_tiles_country_reprojected.crs)

    # Clip raster with projwin (bounding box)
    for i, row in gmw_tiles_country_reprojected.iloc[:].iterrows():
        bounds = row.geometry.bounds  # (minx, miny, maxx, maxy)
        projwin = [bounds[0], bounds[1], bounds[2], bounds[3]]  # [left, bottom, right, top]
        print(f"Polygon {i} {row["tile"]} {row["id"]} projwin:", projwin)

        with rasterio.open(input_tiff_path) as src:
            window = wfb(*projwin, transform=src.transform)
            clipped_data = src.read(window=window)
            transform = src.window_transform(window)

            profile = src.profile
            profile.update({
                "height": clipped_data.shape[1],
                "width": clipped_data.shape[2],
                "transform": transform
            })

            output_clipped_tif = os.path.join(output_tiff_folder , "CLA_" + row["tile"]+"_"+row["id"]+"_"+ year + ".tif")

            with rasterio.open(output_clipped_tif, "w", **profile) as dst:
                dst.write(clipped_data)

        print(f"Clipped raster saved to: {output_clipped_tif}")
        
    print("\n")

def process_gmw_dataset_vector(input_gmw_path, output_gmw_folder, gmw_tiles_country, year):

    # Ensure output directory exists
    os.makedirs(output_gmw_folder, exist_ok=True)

    # Load GMW vector data
    gmw_gdf = gpd.read_file(f"zip://{input_gmw_path}")

    # Reproject GMW to match tiles (assuming gmw_tiles_country is already loaded)
    if gmw_gdf.crs != gmw_tiles_country.crs:
        gmw_tiles_country = gmw_tiles_country.to_crs(gmw_gdf.crs)

    print("Process GMW dataset")
    print("Projection gmw_gdf:", gmw_gdf.crs)
    print("Projection gmw_tiles_country (reprojected):", gmw_tiles_country.crs)

    # Clip by each tile and save as GeoJSON
    for i, row in gmw_tiles_country.iloc[:].iterrows():

        tile_geom = row.geometry

        # Clip GMW data by this tile
        clipped = gpd.clip(gmw_gdf, tile_geom)

        if not clipped.empty:
            output_path = os.path.join(output_gmw_folder, f"GMW_{row['tile']}_{row['id']}_{year}.geojson")
            clipped.to_file(output_path, driver="GeoJSON")
            print(f"Saved: {output_path}")
        else:
            print(f"Tile {row['tile']} produced an empty clip. Skipped.") 
    
    print("\n")

def process_gmw_dataset_buffer(input_gmw_path, output_gmw_folder, gmw_tiles_country, year, buffers, resolution):

    # Ensure output directory exists
    os.makedirs(output_gmw_folder, exist_ok=True)

    # Load GMW vector data
    gmw_gdf = gpd.read_file(f"zip://{input_gmw_path}")

    # Reproject GMW to match tiles (assuming gmw_tiles_country is already loaded)
    if gmw_gdf.crs != gmw_tiles_country.crs:
        gmw_tiles_country = gmw_tiles_country.to_crs(gmw_gdf.crs)

    print("Process GMW dataset")
    print("Projection gmw_gdf:", gmw_gdf.crs)
    print("Projection gmw_tiles_country (reprojected):", gmw_tiles_country.crs)

    # Clip by each tile and rasterize
    for i, row in gmw_tiles_country.iloc[:].iterrows():
        tile = row['tile']
        tile_id = row['id']
        tile_geom = row.geometry

        # Clip GMW data by this tile
        clipped = gpd.clip(gmw_gdf, tile_geom)

        if not clipped.empty:
            # Dissolve and buffer
            dissolved = clipped.dissolve()
            dissolved = dissolved.to_crs("EPSG:3857")

            for b in buffers: 
                buffered = dissolved.buffer(b)
                buffered_gdf = gpd.GeoDataFrame(geometry=buffered, crs="EPSG:3857").to_crs("EPSG:4326")

                # Get bounds and create transform
                tile_geom_proj = gpd.GeoSeries([tile_geom], crs=gmw_tiles_country.crs).to_crs("EPSG:4326").geometry[0]
                minx, miny, maxx, maxy = tile_geom_proj.bounds
                res = resolution  # meters
                width = int((maxx - minx) / res)
                height = int((maxy - miny) / res)
                transform = tfb(minx, miny, maxx, maxy, width, height)

                # Rasterize
                shapes = ((geom, 1) for geom in buffered_gdf.geometry)
                raster = rasterize(
                    shapes=shapes,
                    out_shape=(height, width),
                    transform=transform,
                    fill=0,
                    dtype='uint8'
                )

                # Save raster
                out_raster_path = os.path.join(output_gmw_folder, f"GMW_{tile}_{tile_id}_{year}_{str(b)}.tif")
                with rasterio.open(
                    out_raster_path, "w",
                    driver="GTiff",
                    height=height,
                    width=width,
                    count=1,
                    dtype='uint8',
                    crs="EPSG:4326",
                    transform=transform
                ) as dst:
                    dst.write(raster, 1)

                print(f"Raster saved: {out_raster_path}")
        else:
            print(f"Tile {tile} produced an empty clip. Skipped.")

def get_buffers(input_path, output_folder, gmw_tiles_country, year, buffers, resolution, dataID):

    # Ensure output directory exists
    os.makedirs(output_folder, exist_ok=True)

    # Load GMW vector data
    gdf = gpd.read_file(input_path)

    # Reproject GMW to match tiles (assuming gmw_tiles_country is already loaded)
    if gdf.crs != gmw_tiles_country.crs:
        gmw_tiles_country = gmw_tiles_country.to_crs(gdf.crs)

    print("Process dataset")
    print(F"Projection {dataID}:", gdf.crs)
    print("Projection gmw_tiles_country (reprojected):", gmw_tiles_country.crs)

    # Clip by each tile and rasterize
    for i, row in gmw_tiles_country.iloc[:].iterrows():
        tile = row['tile']
        tile_id = row['id']
        tile_geom = row.geometry

        # Clip GMW data by this tile
        clipped = gpd.clip(gdf, tile_geom)

        if not clipped.empty:
            # Dissolve and buffer
            dissolved = clipped.dissolve()
            dissolved = dissolved.to_crs("EPSG:3857")

            for b in buffers: 
                buffered = dissolved.buffer(b)
                buffered_gdf = gpd.GeoDataFrame(geometry=buffered, crs="EPSG:3857").to_crs("EPSG:4326")

                # Get bounds and create transform
                tile_geom_proj = gpd.GeoSeries([tile_geom], crs=gmw_tiles_country.crs).to_crs("EPSG:4326").geometry[0]
                minx, miny, maxx, maxy = tile_geom_proj.bounds
                res = resolution  # meters
                width = int((maxx - minx) / res)
                height = int((maxy - miny) / res)
                transform = tfb(minx, miny, maxx, maxy, width, height)

                # Rasterize
                shapes = ((geom, 1) for geom in buffered_gdf.geometry)
                raster = rasterize(
                    shapes=shapes,
                    out_shape=(height, width),
                    transform=transform,
                    fill=0,
                    dtype='uint8'
                )

                # Save raster
                out_raster_path = os.path.join(output_folder, f"{dataID}_{tile}_{tile_id}_{year}_{str(b)}.tif")
                with rasterio.open(
                    out_raster_path, "w",
                    driver="GTiff",
                    height=height,
                    width=width,
                    count=1,
                    dtype='uint8',
                    crs="EPSG:4326",
                    transform=transform
                ) as dst:
                    dst.write(raster, 1)

                print(f"Raster saved: {out_raster_path}")
        else:
            print(f"Tile {tile} produced an empty clip. Skipped.")


def get_thiessen_polygons(input_path, output_folder, gmw_tiles_country, year, resolution, buffer_aoi, dataID):

    # Ensure output directory exists
    os.makedirs(output_folder, exist_ok=True)

    # Load GMW vector data
    gdf = gpd.read_file(input_path)
    original_crs = gdf.crs
    gdf = gpd.read_file(input_path).to_crs("EPSG:3857")

    # Reproject GMW to match tiles (assuming gmw_tiles_country is already loaded)
    if gdf.crs != gmw_tiles_country.crs:
        gmw_tiles_country = gmw_tiles_country.to_crs(gdf.crs)

    print("Process dataset")
    print(F"Projection {dataID}:", gdf.crs)
    print("Projection gmw_tiles_country (reprojected):", gmw_tiles_country.crs)

    # Clip by each tile and rasterize
    for i, row in gmw_tiles_country.iloc[:].iterrows():
        tile_geom = row.geometry.buffer(buffer_aoi)

        # Clip GMW data by this tile
        clipped = gpd.clip(gdf, tile_geom)
        clipped = clipped.to_crs(original_crs)

        if not clipped.empty:
            output_path = os.path.join(output_folder, f"GTS_{row['tile']}_{row['id']}_{year}.geojson")
            clipped.to_file(output_path, driver="GeoJSON")
            print(f"Saved: {output_path}")
        else:
            print(f"Tile {row['tile']} produced an empty clip. Skipped.")
 
    print("\n")

def get_tiles_vector(output_folder, gmw_tiles_country, year):
    os.makedirs(output_folder, exist_ok=True)

    for i, row in gmw_tiles_country.iterrows():
        # Convert the row to a GeoDataFrame using .loc[[i]]
        tile_geom = gmw_tiles_country.loc[[i]]

        output_path = os.path.join(output_folder, f"TIL_{row['tile']}_{row['id']}_{year}.geojson")
        tile_geom.to_file(output_path, driver="GeoJSON")

        print(f"Saved: {output_path}")

    print("\n")


def get_tiles_vector_with_buffer(output_folder, gmw_tiles_country, year, buffer_crs, buffer_meters):
    os.makedirs(output_folder, exist_ok=True)

    original_crs = gmw_tiles_country.crs

    for i, row in gmw_tiles_country.iterrows():
        # Select row as GeoDataFrame
        tile_geom = gmw_tiles_country.loc[[i]]

        # Reproject to buffer CRS
        tile_geom_proj = tile_geom.to_crs(buffer_crs)

        # Apply 50 km buffer
        tile_geom_proj['geometry'] = tile_geom_proj.buffer(buffer_meters)

        # Reproject back to original CRS
        tile_geom_buffered = tile_geom_proj.to_crs(original_crs)

        # Output path
        output_path = os.path.join(output_folder, f"TIL_{row['tile']}_{row['id']}_{year}_{str(buffer_meters)}.geojson")

        # Save to GeoJSON
        tile_geom_buffered.to_file(output_path, driver="GeoJSON")

        print(f"Saved: {output_path}")

    print("\n")

# %% [markdown]
# ### Parameters and paths

# %%
# Parameters
analysis_id = 'Indonesia'
tile_year = '2025'

year_clark = '2022'
year_gmw = '2020'
buffers_gmw = [0, 500, 2500, 10000]
resolution_gmw = 0.0002222222222219999985 # Around 24.74 meters 0.0002222222222219999985
year_sho = '2025'
buffers_sho = [250, 500]
resolution_sho = 0.0002222222222219999985 # Around 24.74 meters
year_gts = '2025'
resolution_gts = 0.0002222222222219999985 # Around 24.74 meters
buffer_aoi_gts = 100000

# General paths
geojson_path = r"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\1_Tiles\gmw_v3_tiles.geojson"
srtm_zip_path = r"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\1_Tiles\srtm_grid_1deg.zip"
output_tile_path = fr"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\1_Tiles\{analysis_id}"
countries_path = r"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\2_Countries\countries.geojson"
input_tiff_path = fr"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\3_Clark_classification\{analysis_id}_Landcover_Change_Maps_1999_2014_2018_2020_2022\{analysis_id}_Landcover_{year_clark}_v2exp.tif"
output_tiff_folder = fr"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\3_Clark_classification\{analysis_id}"
input_gmw_path = fr"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\4_GMW\6894273\gmw_v3_{year_gmw}_vec.zip"
output_gmw_folder = fr"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\4_GMW\{analysis_id}"
input_sho_path = r"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\5_Shoreline\GSHHS_i_L1_5km_dissolved_gtsm_coastline_exploded.gpkg"
output_sho_folder = fr"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\5_Shoreline\{analysis_id}"
input_gts_path = r"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\gtsm_tidal_indicators_2022.gpkg"
output_gts_folder = fr"C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\{analysis_id}"

# %% [markdown]
# ### Process tiles

# %%
gmw_tiles_country = get_country_tiles(geojson_path, srtm_zip_path, countries_path, analysis_id)
gmw_tiles_country = gmw_tiles_country[gmw_tiles_country['tile']=='N00E117']
# gmw_tiles_country = gmw_tiles_country.iloc[:10,:]
get_tiles_vector(output_tile_path, gmw_tiles_country, tile_year)
get_tiles_vector_with_buffer(output_tile_path, gmw_tiles_country, tile_year, "EPSG:3857", 10000)
# Out:
# Get country tiles
# Projection gmw_tiles: EPSG:4326
# Projection srtm_grid: EPSG:4326
# Projection countries: EPSG:4326
# Projection gmw_tiles_country: EPSG:4326
# Found 276 polygons overlapping Indonesia.
#
#
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\1_Tiles\Indonesia\TIL_N00E117_S01E117_2025.geojson
#
#
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\1_Tiles\Indonesia\TIL_N00E117_S01E117_2025_10000.geojson

# %% [markdown]
# ### Clark dataset processing

# %%
# process_clark_dataset(gmw_tiles_country, year_clark, input_tiff_path, output_tiff_folder)
# This function is replaced by 3_process_clark.py code

# %% [markdown]
# ### GMW dataset processing

# %%
process_gmw_dataset_vector(input_gmw_path, output_gmw_folder, gmw_tiles_country, year_gmw)
process_gmw_dataset_buffer(input_gmw_path, output_gmw_folder, gmw_tiles_country, year_gmw, buffers_gmw, resolution_gmw)
# Out:
# Process GMW dataset
# Projection gmw_gdf: EPSG:4326
# Projection gmw_tiles_country (reprojected): EPSG:4326
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\4_GMW\Indonesia\GMW_N00E117_S01E117_2020.geojson
#
#
# Process GMW dataset
# Projection gmw_gdf: EPSG:4326
# Projection gmw_tiles_country (reprojected): EPSG:4326
# Raster saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\4_GMW\Indonesia\GMW_N00E117_S01E117_2020_0.tif
# Raster saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\4_GMW\Indonesia\GMW_N00E117_S01E117_2020_500.tif

# %% [markdown]
# ### Shoreline dataset processing

# %%
# get_buffers(input_sho_path, output_sho_folder, gmw_tiles_country, year_sho, buffers_sho, resolution_sho, 'SHO')

# %% [markdown]
# ### GTSM dataset processing

# %%
get_thiessen_polygons(input_gts_path, output_gts_folder, gmw_tiles_country, year_gts, resolution_gts, buffer_aoi_gts, 'GTS')
# Out:
# Process dataset
# Projection GTS: EPSG:3857
# Projection gmw_tiles_country (reprojected): EPSG:3857
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E140_S09E140_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E109_S02E109_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E096_N02E096_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E108_S03E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E126_S04E126_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E133_S04E133_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E124_S09E124_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E120_N01E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E131_S09E131_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E121_N00E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E124_S06E124_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E138_S07E138_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E129_N00E129_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E139_S09E139_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E128_N01E128_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E106_N02E106_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E100_S03E100_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E099_S02E099_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E109_N02E109_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S09E118_S10E118_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E123_S06E123_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N04E125_N03E125_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E127_N01E127_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E123_S09E123_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E134_S04E134_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E121_S04E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E129_S04E129_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E105_S05E105_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S10E120_S11E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E099_N02E099_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E112_S03E112_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E107_S03E107_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E101_N02E101_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E098_S01E098_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E128_S04E128_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E106_S03E106_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E113_S03E113_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E099_S01E099_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E100_N02E100_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N05E117_N04E117_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E119_S05E119_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E109_S01E109_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S09E119_S10E119_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E108_N02E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E122_S09E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E137_S09E137_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E120_S04E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E135_S04E135_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E127_N00E127_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E122_S06E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E137_S06E137_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E138_S09E138_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E128_N00E128_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E138_S06E138_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E139_S07E139_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E116_S05E116_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E100_S02E100_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E099_S03E099_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E098_S02E098_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E101_S03E101_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E108_S02E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E097_N02E097_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E131_S07E131_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E124_S07E124_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E120_N00E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E132_S04E132_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E127_S04E127_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E130_S09E130_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E125_S09E125_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E121_N01E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E116_S03E116_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E105_N02E105_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E104_S01E104_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N05E107_N04E107_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S10E124_S11E124_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E114_S05E114_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E115_S08E115_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E127_S09E127_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E130_S04E130_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E125_S04E125_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E122_N00E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E132_S06E132_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E108_S08E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N05E097_N04E097_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E119_S01E119_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E095_N02E095_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E118_N02E118_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N05E098_N04E098_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E112_S08E112_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S10E123_S11E123_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N05E115_N04E115_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E105_S02E105_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E110_S02E110_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E103_S01E103_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E116_S01E116_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E117_N02E117_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E104_S03E104_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E111_S03E111_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E134_S07E134_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E120_S06E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E122_S04E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E124_N01E124_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E120_S09E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E119_S03E119_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N05E108_N04E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E123_S04E123_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E125_N01E125_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E121_S09E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E124_N00E124_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E134_S06E134_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E121_S06E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E120_S07E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E119_S02E119_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E118_S03E118_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E110_S03E110_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E105_S03E105_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E104_S02E104_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E117_S01E117_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S10E122_S11E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E113_S08E113_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E133_S06E133_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E123_N00E123_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E122_N01E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N06E097_N05E097_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E109_S08E109_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E114_S08E114_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E115_S05E115_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E103_S02E103_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E116_S02E116_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E117_N00E117_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E102_N00E102_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E112_S09E112_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E103_N01E103_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E110_S04E110_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E105_S04E105_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N04E099_N03E099_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E113_S07E113_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E106_S07E106_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E112_S06E112_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E107_S06E107_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E131_S01E131_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E137_S02E137_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E122_S02E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E136_S03E136_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E123_S03E123_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E125_N02E125_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E120_S08E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N05E127_N04E127_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E134_S05E134_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E121_S05E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E118_S04E118_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N04E106_N03E106_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E104_N01E104_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E115_S09E115_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E111_N01E111_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E138_S02E138_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E139_S03E139_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E133_S05E133_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E124_S03E124_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E125_S02E125_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E130_S02E130_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E123_S01E123_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E118_N00E118_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E109_S07E109_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E140_S03E140_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E131_S02E131_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E124_S02E124_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E122_S01E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E130_S03E130_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E125_S03E125_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E132_S05E132_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E108_S07E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E118_N01E118_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E119_N00E119_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E104_N00E104_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E116_S04E116_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E114_S09E114_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E110_N01E110_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E115_S07E115_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N04E107_N03E107_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E120_S05E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E135_S05E135_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E121_S08E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E122_S03E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E137_S03E137_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S09E120_S10E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E130_S01E130_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E123_S02E123_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E136_S02E136_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E119_S04E119_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N04E108_N03E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E106_S06E106_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N04E098_N03E098_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E107_S07E107_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E112_S07E112_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E102_N01E102_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E117_N01E117_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E111_S04E111_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E103_N00E103_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E129_S08E129_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E119_S06E119_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E119_S09E119_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E108_N01E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E109_N00E109_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E121_S02E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E134_S02E134_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E127_S01E127_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E120_S03E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E135_S03E135_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E122_S05E122_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E137_S05E137_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E128_S03E128_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E129_S02E129_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E098_N01E098_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E106_S04E106_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E113_S04E113_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E099_N00E099_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E105_S07E105_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S06E110_S07E110_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N04E117_N03E117_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E104_S06E104_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E097_N01E097_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E140_S08E140_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E131_S08E131_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E132_S03E132_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E127_S03E127_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S09E125_S10E125_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E135_S01E135_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E120_S01E120_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E126_S02E126_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E128_S01E128_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E139_S08E139_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E103_S06E103_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N04E105_N03E105_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E116_S09E116_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E114_S04E114_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E138_S08E138_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E128_N02E128_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E129_S01E129_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E107_N00E107_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E117_S09E117_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E100_S04E100_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E115_S04E115_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E102_S06E102_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S09E140_S10E140_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E097_N00E097_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E108_S04E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E121_S01E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N00E134_S01E134_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E127_S02E127_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E132_S02E132_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E126_S03E126_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E133_S03E133_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S09E124_S10E124_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E125_S08E125_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E130_S08E130_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E131_S05E131_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E128_S02E128_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E129_S03E129_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E110_S06E110_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S05E105_S06E105_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E112_S04E112_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S03E107_S04E107_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E098_N00E098_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E101_N01E101_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N01E108_N00E108_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N02E109_N01E109_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S08E118_S09E118_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E136_S05E136_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S04E123_S05E123_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S07E137_S08E137_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_N03E127_N02E127_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E134_S03E134_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S02E121_S03E121_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E135_S02E135_2025.geojson
# Saved: C:\Ocean\Work\Projects\2025\Mangroves\Data\0_Workflow\8_Tides\Indonesia\GTS_S01E120_S02E120_2025.geojson

# %%
# Base map: all tiles
m = gmw_tiles.explore(
    color="blue",
    style_kwds=dict(weight=1),
    name="All Tiles"
)

# Add overlapping tiles (highlighted in red)
gmw_tiles_overlapping_indonesia.explore(
    m=m,
    color="yellow",
    style_kwds=dict(weight=2),
    name="Overlapping with Indonesia"
)

# Add Indonesia boundary (highlighted in blue)
indonesia.explore(
    m=m,
    color="blue",
    style_kwds=dict(weight=2, fill=False),
    name="Indonesia"
)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f6ee2546aa76aeb2ba7745f16595415 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f6ee2546aa76aeb2ba7745f16595415&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f6ee2546aa76aeb2ba7745f16595415 = L.map(
#                 &quot;map_3f6ee2546aa76aeb2ba7745f16595415&quot;,
#                 {
#                     center: [-2.9999999999994955, -4.973799150320701e-13],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3f6ee2546aa76aeb2ba7745f16595415);
#
#
#
#
#
#             var tile_layer_77935a6caaf20c24efd6eeb71196226a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77935a6caaf20c24efd6eeb71196226a.addTo(map_3f6ee2546aa76aeb2ba7745f16595415);
#
#
#             map_3f6ee2546aa76aeb2ba7745f16595415.fitBounds(
#                 [[-38.99999999999899, -180.0], [33.0, 179.999999999999]],
#                 {}
#             );
#
#
#         function geo_json_2c09c5f958027d111783f80a7f736214_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_2c09c5f958027d111783f80a7f736214_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_2c09c5f958027d111783f80a7f736214_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_2c09c5f958027d111783f80a7f736214_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_2c09c5f958027d111783f80a7f736214_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_2c09c5f958027d111783f80a7f736214.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2c09c5f958027d111783f80a7f736214_highlighter(e.target.feature)

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, LineString

# --- LOAD DATA ---
file_path = r'p:\11211992-tki-mangrove-restoration\01_data\GIN_annual_coastlinesnewdatabase.xlsx'
df = pd.read_excel(file_path)

# Create GeoDataFrame
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df['Intersect_lon'], df['Intersect_lat']),
    crs='EPSG:4326'  # WGS84
)

# Project to UTM zone for distance in meters (you may want to adjust zone depending on location)
gdf = gdf.to_crs(epsg=32630)  # Example: UTM Zone 30N. Change to fit your region.
gdf
# Out:
#         transect_id country_id continent analysis_id  changerate  flag_sandy  \
# 0     BOX_120_138_1        GIN    Africa       Guinea   -0.721394           0
# 1     BOX_120_138_2        GIN    Africa       Guinea   23.900228           0
# 2     BOX_120_138_3        GIN    Africa       Guinea    0.325190           0
# 3     BOX_120_138_4        GIN    Africa       Guinea   12.720222           0
# 4     BOX_120_138_5        GIN    Africa       Guinea   -0.280219           0
# ...             ...        ...       ...          ...         ...         ...
# 1396  BOX_120_092_2        GIN    Africa       Guinea   -0.085719           0
# 1397  BOX_120_092_3        GIN    Africa       Guinea   -0.304848           0
# 1398  BOX_120_092_4        GIN    Africa       Guinea    0.013182           0
# 1399  BOX_120_092_5        GIN    Africa       Guinea    0.045844           0
# 1400  BOX_120_092_6        GIN    Africa       Guinea    0.521075           0
#
#       no_shorelines                                                 dt  \
# 0                27  [0.0, 2.00141002211, 3.00074607966, 4.00008213...
# 1                28  [0.0, 2.00141002211, 3.00074607966, 4.00008213...
# 2                25  [0.0, 2.00141002211, 4.00008213721, 5.00215610...
# 3                26  [0.0, 2.00141002211, 4.00008213721, 5.00215610...
# 4                26  [0.0, 2.00141002211, 4.00008213721, 5.00215610...
# ...             ...                                                ...
# 1396             26  [2.00141002211, 4.00008213721, 5.00215610177, ...
# 1397             26  [2.00141002211, 4.00008213721, 5.00215610177, ...
# 1398             26  [2.00141002211, 4.00008213721, 5.00215610177, ...
# 1399             27  [0.0, 2.00141002211, 4.00008213721, 5.00215610...
# 1400             26  [2.00141002211, 4.00008213721, 5.00215610177, ...
#
#                                                    dist        RMSE  \
# 0     [667.2971744321869, 688.2593170940436, 590.212...   10.198030
# 1     [563.8547748270179, 1372.0799026502502, 520.07...  346.112856
# 2     [814.4243780662981, 1409.181999377978, 816.417...    6.790827
# 3     [1919.3530227647232, 1917.4780679970195, 974.8...  240.892656
# 4     [558.7977684773145, 559.1314364108003, 583.593...    6.920151
# ...                                                 ...         ...
# 1396  [10.386510255878939, 18.036874705639196, 21.04...   11.974588
# 1397  [396.08682254128803, 413.5287941046127, 499.20...   13.806049
# 1398  [221.51308658793687, 241.05817835151424, 302.8...    9.196955
# 1399  [1673.4146451301103, 785.1318077013193, 788.23...   12.687321
# 1400  [962.573344095634, 941.8154524776764, 925.8208...   13.993398
#
#                      outliers_1 outliers_2  Timespan    intercept  \
# 0                           [6]        [2]        32   661.552186
# 1     [0, 1, 4, 5, 6, 7, 8, 23]         []        29   464.804229
# 2              [1, 2, 3, 4, 20]        [0]        21  1394.646535
# 3                   [6, 11, 15]       [22]        31  1600.197428
# 4                            []        [5]        32   571.525605
# ...                         ...        ...       ...          ...
# 1396                        [6]        [9]        30    26.677486
# 1397                         []        [2]        30   417.821343
# 1398                         []     [2, 6]        30   235.027406
# 1399                         []        [0]        30   790.055615
# 1400                         []        [4]        30   947.701233
#
#       Intersect_lon  Intersect_lat                         geometry
# 0        -13.188671       9.179224  POINT (-624998.729 1030750.683)
# 1        -13.184772       9.177207   POINT (-624570.35 1030511.807)
# 2        -13.180851       9.175191  POINT (-624139.451 1030272.925)
# 3        -13.176380       9.174989   POINT (-623641.43 1030236.033)
# 4        -13.171954       9.175436  POINT (-623146.369 1030272.027)
# ...             ...            ...                              ...
# 1396     -13.793646       9.508386  POINT (-691393.513 1069762.463)
# 1397     -13.792542       9.512347  POINT (-691256.241 1070204.081)
# 1398     -13.796791       9.513597  POINT (-691726.139 1070359.542)
# 1399     -13.801250       9.513760  POINT (-692223.353 1070393.604)
# 1400     -13.805735       9.513519   POINT (-692724.89 1070382.248)
#
# [1401 rows x 17 columns]

# %%
# --- EXTRACT ID COMPONENTS ---
gdf['base_id'] = gdf['transect_id'].apply(lambda x: '_'.join(x.split('_')[:3]))
gdf['point_num'] = gdf['transect_id'].apply(lambda x: int(x.split('_')[-1]))

# Sort points
gdf_sorted = gdf.sort_values(by=['base_id', 'point_num'])

# --- GENERATE LINES WITH DISTANCE FILTER ---
lines = []

for base_id, group in gdf_sorted.groupby('base_id'):
    group = group.sort_values('point_num').reset_index(drop=True)
    current_line = [group.geometry.iloc[0]]

    for i in range(1, len(group)):
        prev_num = group['point_num'].iloc[i - 1]
        curr_num = group['point_num'].iloc[i]
        dist = group.geometry.iloc[i].distance(group.geometry.iloc[i - 1])

        # Only connect if consecutive AND within 600 meters
        if curr_num == prev_num + 1 and dist <= 600:
            current_line.append(group.geometry.iloc[i])
        else:
            if len(current_line) >= 2:
                lines.append({'transect_id': base_id, 'geometry': LineString(current_line)})
            current_line = [group.geometry.iloc[i]]

    if len(current_line) >= 2:
        lines.append({'transect_id': base_id, 'geometry': LineString(current_line)})

# Create GeoDataFrame with lines
lines_gdf = gpd.GeoDataFrame(lines, crs=gdf.crs)

# --- EXPLORE BOTH ---
# Reproject to EPSG:4326 for display
gdf = gdf.to_crs(epsg=4326)
lines_gdf = lines_gdf.to_crs(epsg=4326)

m = gdf.explore(color="blue", marker_kwds={"radius": 4}, tooltip="transect_id")
lines_gdf.explore(m=m, color="red", tooltip="transect_id")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4323d6cf9acee9e183f52655acf6ca45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4323d6cf9acee9e183f52655acf6ca45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4323d6cf9acee9e183f52655acf6ca45 = L.map(
#                 &quot;map_4323d6cf9acee9e183f52655acf6ca45&quot;,
#                 {
#                     center: [9.956234421569999, -14.109613638799999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4323d6cf9acee9e183f52655acf6ca45);
#
#
#
#
#
#             var tile_layer_c7eaa47dc4ff3365a7de62ac09a1eef5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7eaa47dc4ff3365a7de62ac09a1eef5.addTo(map_4323d6cf9acee9e183f52655acf6ca45);
#
#
#             map_4323d6cf9acee9e183f52655acf6ca45.fitBounds(
#                 [[8.95072870834, -15.1052814601], [10.9617401348, -13.1139458175]],
#                 {}
#             );
#
#
#         function geo_json_aefc921b55dd5ec7a609e5c789059ae1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_aefc921b55dd5ec7a609e5c789059ae1_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_aefc921b55dd5ec7a609e5c789059ae1_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 4,
# };
#
#             let style = geo_json_aefc921b55dd5ec7a609e5c789059ae1_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_aefc921b55dd5ec7a609e5c789059ae1_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_aefc921b55dd5ec7a609e5c789059ae1.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_aefc921b55dd5ec7a609e5c789059ae1_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_aefc921b55dd5ec7a609e5c789059ae1 = L.geoJson(null, {
#                 onEachFeature: geo_json_aefc921b55dd5ec7a609e5c789059ae1_onEachFeature,
#
#                 style: geo_json_aefc921b55dd5ec7a609e5c789059ae1_styler,
#                 pointToLayer: geo_json_aefc921b55dd5ec7a609e5c789059ae1_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_aefc921b55dd5ec7a609e5c789059ae1_a

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, LineString
import folium

# --- LOAD DATA ---
file_path = r'p:\11211992-tki-mangrove-restoration\01_data\GIN_annual_coastlinesnewdatabase.xlsx'
df = pd.read_excel(file_path)

# Create GeoDataFrame with WGS84 coordinates
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df['Intersect_lon'], df['Intersect_lat']),
    crs='EPSG:4326'
)

# Project to UTM (metric system, adjust EPSG if necessary)
gdf = gdf.to_crs(epsg=32630)  # Use appropriate UTM zone

# --- EXTRACT ID COMPONENTS ---
gdf['base_id'] = gdf['transect_id'].apply(lambda x: '_'.join(x.split('_')[:3]))
gdf['point_num'] = gdf['transect_id'].apply(lambda x: int(x.split('_')[-1]))

# Sort points
gdf_sorted = gdf.sort_values(by=['base_id', 'point_num'])

# --- GENERATE LINES WITH DISTANCE FILTER ---
lines = []

for base_id, group in gdf_sorted.groupby('base_id'):
    group = group.sort_values('point_num').reset_index(drop=True)
    current_line = [group.geometry.iloc[0]]

    for i in range(1, len(group)):
        prev_num = group['point_num'].iloc[i - 1]
        curr_num = group['point_num'].iloc[i]
        dist = group.geometry.iloc[i].distance(group.geometry.iloc[i - 1])

        # Only connect if consecutive AND within 600 meters
        if curr_num == prev_num + 1 and dist <= 600:
            current_line.append(group.geometry.iloc[i])
        else:
            if len(current_line) >= 2:
                lines.append({'transect_id': base_id, 'geometry': LineString(current_line)})
            current_line = [group.geometry.iloc[i]]

    if len(current_line) >= 2:
        lines.append({'transect_id': base_id, 'geometry': LineString(current_line)})

# Create GeoDataFrame with lines
lines_gdf = gpd.GeoDataFrame(lines, crs=gdf.crs)

# --- CREATE BUFFERS ---
buffer_250 = lines_gdf.copy()
buffer_250['geometry'] = buffer_250.geometry.buffer(250)

buffer_500 = lines_gdf.copy()
buffer_500['geometry'] = buffer_500.geometry.buffer(500)

# --- REPROJECT TO WGS84 FOR DISPLAY ---
gdf = gdf.to_crs(epsg=4326)
lines_gdf = lines_gdf.to_crs(epsg=4326)
buffer_250 = buffer_250.to_crs(epsg=4326)
buffer_500 = buffer_500.to_crs(epsg=4326)

# --- EXPLORE ALL LAYERS ---
m = gdf.explore(color="blue", marker_kwds={"radius": 4}, tooltip="transect_id", name="Points")
m = lines_gdf.explore(m=m, color="red", tooltip="transect_id", name="Lines")
m = buffer_250.explore(m=m, color="green", style_kwds={'fillOpacity': 0.2}, name="Buffer 250m")
m = buffer_500.explore(m=m, color="orange", style_kwds={'fillOpacity': 0.1}, name="Buffer 500m")

# Add layer control
# folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88d744913aed27b2e7dcc4ffb7da8953 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88d744913aed27b2e7dcc4ffb7da8953&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88d744913aed27b2e7dcc4ffb7da8953 = L.map(
#                 &quot;map_88d744913aed27b2e7dcc4ffb7da8953&quot;,
#                 {
#                     center: [9.956234421569999, -14.109613638799999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_88d744913aed27b2e7dcc4ffb7da8953);
#
#
#
#
#
#             var tile_layer_ae85fe1319acf33232ab4d589627b76a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ae85fe1319acf33232ab4d589627b76a.addTo(map_88d744913aed27b2e7dcc4ffb7da8953);
#
#
#             map_88d744913aed27b2e7dcc4ffb7da8953.fitBounds(
#                 [[8.95072870834, -15.1052814601], [10.9617401348, -13.1139458175]],
#                 {}
#             );
#
#
#         function geo_json_76470989b04e975b1912a4a224f0929a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_76470989b04e975b1912a4a224f0929a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_76470989b04e975b1912a4a224f0929a_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 4,
# };
#
#             let style = geo_json_76470989b04e975b1912a4a224f0929a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_76470989b04e975b1912a4a224f0929a_onEachFe

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, LineString
from shapely.ops import voronoi_diagram
import folium

# --- STEP 1: LOAD POINT DATA ---
file_path = r'p:\11211992-tki-mangrove-restoration\01_data\GIN_annual_coastlinesnewdatabase.xlsx'
df = pd.read_excel(file_path)

# Create GeoDataFrame in WGS84
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df['Intersect_lon'], df['Intersect_lat']),
    crs='EPSG:4326'
)

# Project to metric CRS (UTM zone 30N – change if needed)
gdf = gdf.to_crs(epsg=32630)

# --- STEP 2: EXTRACT ID COMPONENTS AND SORT ---
gdf['base_id'] = gdf['transect_id'].apply(lambda x: '_'.join(x.split('_')[:3]))
gdf['point_num'] = gdf['transect_id'].apply(lambda x: int(x.split('_')[-1]))
gdf_sorted = gdf.sort_values(by=['base_id', 'point_num'])

# --- STEP 3: CONNECT POINTS INTO LINES ---
lines = []
for base_id, group in gdf_sorted.groupby('base_id'):
    group = group.sort_values('point_num').reset_index(drop=True)
    current_line = [group.geometry.iloc[0]]

    for i in range(1, len(group)):
        prev_num = group['point_num'].iloc[i - 1]
        curr_num = group['point_num'].iloc[i]
        dist = group.geometry.iloc[i].distance(group.geometry.iloc[i - 1])

        if curr_num == prev_num + 1 and dist <= 600:
            current_line.append(group.geometry.iloc[i])
        else:
            if len(current_line) >= 2:
                lines.append({'transect_id': base_id, 'geometry': LineString(current_line)})
            current_line = [group.geometry.iloc[i]]

    if len(current_line) >= 2:
        lines.append({'transect_id': base_id, 'geometry': LineString(current_line)})

lines_gdf = gpd.GeoDataFrame(lines, crs=gdf.crs)

# --- STEP 4: CREATE BUFFERS ---
buffer_250 = lines_gdf.copy()
buffer_250['geometry'] = buffer_250.geometry.buffer(250)

buffer_500 = lines_gdf.copy()
buffer_500['geometry'] = buffer_500.geometry.buffer(500)

# --- STEP 5: GENERATE THIESSEN (VORONOI) POLYGONS ---
multi_point = gdf.unary_union
bounds = multi_point.convex_hull.buffer(1000)
vor = voronoi_diagram(multi_point, envelope=bounds)

voronoi_gdf = gpd.GeoDataFrame(
    geometry=[poly for poly in vor.geoms],
    crs=gdf.crs
)

# Assign transect_id to Voronoi polygons via spatial join
# point_poly_join = gpd.sjoin(
#     voronoi_gdf, gdf[['transect_id', 'geometry']],
#     how='left',
#     predicate='contains'
# ).drop(columns='index_right').dropna(subset=['transect_id'])

# # --- STEP 6: CLIP THIESSEN POLYGONS TO 500 m BUFFER ---
# clipped_voronoi = gpd.overlay(point_poly_join, buffer_500, how='intersection')

# # --- STEP 7: REPROJECT ALL LAYERS TO EPSG:4326 FOR DISPLAY ---
# gdf = gdf.to_crs(epsg=4326)
# lines_gdf = lines_gdf.to_crs(epsg=4326)
# buffer_250 = buffer_250.to_crs(epsg=4326)
# buffer_500 = buffer_500.to_crs(epsg=4326)
# clipped_voronoi = clipped_voronoi.to_crs(epsg=4326)

# # --- STEP 8: DISPLAY INTERACTIVE MAP ---
# m = gdf.explore(color="blue", marker_kwds={"radius": 4}, tooltip="transect_id", name="Points")
# m = lines_gdf.explore(m=m, color="red", tooltip="transect_id", name="Lines")
# m = buffer_250.explore(m=m, color="green", style_kwds={'fillOpacity': 0.2}, name="Buffer 250 m")
# m = buffer_500.explore(m=m, color="orange", style_kwds={'fillOpacity': 0.1}, name="Buffer 500 m")
# m = clipped_voronoi.explore(m=m, column="transect_id", cmap="Pastel1", tooltip="transect_id", name="Thiessen (Clipped)")

# # folium.LayerControl().add_to(m)
# m
# Out:
# C:\Users\fuentesm\AppData\Local\Temp\ipykernel_20828\1776269334.py:57: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   multi_point = gdf.unary_union

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, LineString
from shapely.ops import voronoi_diagram
import folium

# --- STEP 1: LOAD POINT DATA ---
file_path = r'p:\11211992-tki-mangrove-restoration\01_data\GIN_annual_coastlinesnewdatabase.xlsx'
df = pd.read_excel(file_path)

# Create GeoDataFrame in WGS84
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df['Intersect_lon'], df['Intersect_lat']),
    crs='EPSG:4326'
)

# Project to metric CRS (UTM zone 30N – change if needed)
gdf = gdf.to_crs(epsg=32630)

# --- STEP 2: EXTRACT ID COMPONENTS AND SORT ---
gdf['base_id'] = gdf['transect_id'].apply(lambda x: '_'.join(x.split('_')[:3]))
gdf['point_num'] = gdf['transect_id'].apply(lambda x: int(x.split('_')[-1]))
gdf_sorted = gdf.sort_values(by=['base_id', 'point_num'])

# --- STEP 3: CONNECT POINTS INTO LINES ---
lines = []
for base_id, group in gdf_sorted.groupby('base_id'):
    group = group.sort_values('point_num').reset_index(drop=True)
    current_line = [group.geometry.iloc[0]]

    for i in range(1, len(group)):
        prev_num = group['point_num'].iloc[i - 1]
        curr_num = group['point_num'].iloc[i]
        dist = group.geometry.iloc[i].distance(group.geometry.iloc[i - 1])

        if curr_num == prev_num + 1 and dist <= 600:
            current_line.append(group.geometry.iloc[i])
        else:
            if len(current_line) >= 2:
                lines.append({'transect_id': base_id, 'geometry': LineString(current_line)})
            current_line = [group.geometry.iloc[i]]

    if len(current_line) >= 2:
        lines.append({'transect_id': base_id, 'geometry': LineString(current_line)})

lines_gdf = gpd.GeoDataFrame(lines, crs=gdf.crs)

# --- STEP 4: CREATE BUFFERS ---
buffer_250 = lines_gdf.copy()
buffer_250['geometry'] = buffer_250.geometry.buffer(250)

buffer_500 = lines_gdf.copy()
buffer_500['geometry'] = buffer_500.geometry.buffer(500)

# --- STEP 5: GENERATE THIESSEN (VORONOI) POLYGONS ---
multi_point = gdf.unary_union
bounds = multi_point.convex_hull.buffer(1000)
vor = voronoi_diagram(multi_point, envelope=bounds)

voronoi_gdf = gpd.GeoDataFrame(
    geometry=[poly for poly in vor.geoms],
    crs=gdf.crs
)

# --- STEP 6: CLIP VORONOI POLYGONS WITH 500m BUFFER ---
buffer_500_union = buffer_500.unary_union  # Dissolve all buffers into one geometry

voronoi_clipped = voronoi_gdf.copy()
voronoi_clipped['geometry'] = voronoi_clipped.geometry.intersection(buffer_500_union)

# Remove empty geometries that fall outside the buffer
voronoi_clipped = voronoi_clipped[~voronoi_clipped.is_empty].reset_index(drop=True)
voronoi_clipped.explore()

# Optional: save or inspect the clipped Voronoi polygons
# voronoi_clipped.to_file('voronoi_clipped.shp')  # Example to save shapefile
# Out:
# C:\Users\fuentesm\AppData\Local\Temp\ipykernel_18640\737664007.py:57: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   multi_point = gdf.unary_union
# C:\Users\fuentesm\AppData\Local\Temp\ipykernel_18640\737664007.py:67: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   buffer_500_union = buffer_500.unary_union  # Dissolve all buffers into one geometry
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7470a6bedb8b0f921f735aeceddb6e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7470a6bedb8b0f921f735aeceddb6e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7470a6bedb8b0f921f735aeceddb6e5 = L.map(
#                 &quot;map_c7470a6bedb8b0f921f735aeceddb6e5&quot;,
#                 {
#                     center: [9.9562216081944, -14.109611691773484],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c7470a6bedb8b0f921f735aeceddb6e5);
#
#
#
#
#
#             var tile_layer_2e5e2e28a017fedb8ba6f3394ecac2cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e5e2e28a017fedb8ba6f3394ecac2cf.addTo(map_c7470a6bedb8b0f921f735aeceddb6e5);
#
#
#             map_c7470a6bedb8b0f921f735aeceddb6e5.fitBounds(
#                 [[8.946278590620146, -15.109759055905885], [10.966164625768657, -13.109464327641085]],
#                 {}
#             );
#
#
#         function geo_json_5aa97f36364aad97b9768518e1f62d99_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5aa97f36364aad97b9768518e1f62d99_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5aa97f36364aad97b9768518e1f62d99_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_5aa97f36364aad97b9768518e1f62d99_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5aa97f36364aad97b9768518e1f62d99_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5aa97f36364aad97b9768518e1f62d99.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5aa97f36364aad97b9768518e1f62d99_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5aa97f36364aad97b9768518e1f62d99 = L.geoJson(null, {
#                 onEachFeature: geo_json_5aa97f36364aad97b9768518e1f62d99_onEachFeature,
#
#                 style: geo_json_5aa97f36364aad97b9768518e1f62d99_styler,
#                 pointToLayer: geo_json_5aa97f36364aad97b9768518e1f62d99_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5aa97f36364aad97b9768518e1f62d99_add (data) {
#             geo_json_5aa97f36364aad97b9768518e1f62d99
#                 .addData(data);
#         }
#             geo_json_5aa97f36364aad97b9768518e1f62d99_add({&quot;bbox&quot;: [-15.109759055905885, 8.946278590620146, -13.109464327641085, 10.966164625768657], &quot;features&quot;: [{&quot;bbox&quot;: [-15.109759055905885, 10.95770827699573, -15.100283962660978, 10.966164625768657], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-15.1081713153218, 10.95770827699573], [-15.109225076293603, 10.959644735275434], [-15.109413937506185, 10.960036777218937], [-15.109563002150606, 10.960445222
